# %% [markdown]
# # Removing columns from Data

# %%
# conventional way to import pandas
import pandas as pd

# %%
# read a dataset of top-rated tweets into a DataFrame
df=pd.read_csv('http://bit.ly/tweetsdf')

# %%
# show the first 5 rows
df.head()
# Out:
#       author                                            content  \
# 0  katyperry  Is history repeating itself...?#DONTNORMALIZEH...
# 1  katyperry  @barackobama Thank you for your incredible gra...
# 2  katyperry                Life goals. https://t.co/XIn1qKMKQl
# 3  katyperry            Me right now 🙏🏻 https://t.co/gW55C1wrwd
# 4  katyperry  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...
#
#           date_time language  number_of_likes  number_of_shares
# 0  12-01-2017 19:52       en             7900              3472
# 1  11-01-2017 08:38       en             3689              1380
# 2  11-01-2017 02:52       en            10341              2387
# 3  11-01-2017 02:44       en            10774              2458
# 4  10-01-2017 05:22       en            17620              4655

# %%
# shows the columns of a DataFrame
df.columns
# Out:
# Index(['author', 'content', 'date_time', 'language', 'number_of_likes',
#        'number_of_shares'],
#       dtype='object')

# %%
# sort the values of a column in the dataframe, with arguments
df.number_of_shares.sort_values(ascending=False)
# or equivalent use bracket notation
df[number_of_shares].sort_values(ascending=False)
# Out:
# 26521    219062
# 8520     200747
# 4568     199229
# 3345     186074
# 3467     185758
#           ...
# 14918         0
# 15231         0
# 13964         0
# 43336         0
# 12949         0
# Name: number_of_shares, Length: 52542, dtype: int64

# %%
# remove a single column (axis=1 refers to columns)
df.drop('content',axis=1)
# Out:
#           author         date_time language  number_of_likes  number_of_shares
# 0      katyperry  12-01-2017 19:52       en             7900              3472
# 1      katyperry  11-01-2017 08:38       en             3689              1380
# 2      katyperry  11-01-2017 02:52       en            10341              2387
# 3      katyperry  11-01-2017 02:44       en            10774              2458
# 4      katyperry  10-01-2017 05:22       en            17620              4655
# ...          ...               ...      ...              ...               ...
# 52537   ddlovato  06-01-2015 23:10       en            32799             23796
# 52538   ddlovato  06-01-2015 02:17       en            21709             12511
# 52539   ddlovato  05-01-2015 03:42       en            25269             15583
# 52540   ddlovato  05-01-2015 00:06      und            15985             10456
# 52541   ddlovato  05-01-2015 00:02      und            16193             10822
#
# ...

# %%
# remove multiple columns at once(using lists)
df.drop(['author', 'number_of_shares'], axis=1)
# Out:
#                                                  content         date_time  \
# 0      Is history repeating itself...?#DONTNORMALIZEH...  12-01-2017 19:52
# 1      @barackobama Thank you for your incredible gra...  11-01-2017 08:38
# 2                    Life goals. https://t.co/XIn1qKMKQl  11-01-2017 02:52
# 3                Me right now 🙏🏻 https://t.co/gW55C1wrwd  11-01-2017 02:44
# 4      SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...  10-01-2017 05:22
# ...                                                  ...               ...
# 52537               Life couldn't be better right now. 😊  06-01-2015 23:10
# 52538  First Monday back in action. I'd say 21.6 mile...  06-01-2015 02:17
# 52539  Crime shows, buddy, snuggles = the perfect Sun...  05-01-2015 03:42
# 52540                          ❄️ http://t.co/sHCFdPpGPa  05-01-2015 00:06
# 52541                      ❤️❄️✈️ http://t.co/ixmB5lv17Z  05-01-2015 00:02
#
#       language  number_of_likes
# 0           en             7900
# ...

# %%
#DataFrames to practice with
                    #http://bit.ly/tweetsdf               http://bit.ly/moviebyuser
